# %% [markdown]
# # INTRODUCTION TO OPENCV AND IMAGE PROCESSING
# pip install opencv-python
#
# MATPLOTLIB --> R G B ;
# OPEN C V CHANNEL --> B G R

# %%
#pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
#horse
# img1 = cv2.imread(r'C:\Users\satya\OneDrive\Documents\NareshIT\Prakash_Sena_Sir\Python\Horse_Image.jpeg')

# %%
# elephant
img1 = cv2.imread(r'C:\Users\satya\OneDrive\Documents\NareshIT\Prakash_Sena_Sir\Python\Elephant_image.jpg')

# %%
plt.imshow(img1)

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
img1.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(img1)

# %%
img1
# Out:
# array([[[206, 198, 199],
#         [206, 198, 199],
#         [206, 198, 199],
#         ...,
#         [206, 200, 201],
#         [206, 200, 201],
#         [206, 200, 201]],
#
#        [[206, 198, 199],
#         [206, 198, 199],
#         [206, 198, 199],
#         ...,
#         [206, 200, 201],
#         [206, 200, 201],
#         [206, 200, 201]],
#
#        [[206, 198, 199],
#         [206, 198, 199],
#         [206, 198, 199],
#         ...,
#         [206, 200, 201],
#         [206, 200, 201],
#         [206, 200, 201]],
#
#        ...,
#
#        [[105, 148, 157],
#         [104, 147, 156],
#         [115, 158, 167],
#         ...,
#         [ 94, 135, 138],
#         [112, 153, 156],
#         [104, 144, 149]],
#
#        [[134, 179, 192],
#         [117, 162, 175],
#         [ 92, 137, 150],
#         ...,
#         [106, 143, 147],
#         [123, 160, 164],
#         [122, 158, 164]],
#
#        [[106, 155, 169],
#         [112, 161, 175],
#         [ 97, 146, 160],
# ...

# %%
fix_img = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
fix_img
# Out:
# array([[[199, 198, 206],
#         [199, 198, 206],
#         [199, 198, 206],
#         ...,
#         [201, 200, 206],
#         [201, 200, 206],
#         [201, 200, 206]],
#
#        [[199, 198, 206],
#         [199, 198, 206],
#         [199, 198, 206],
#         ...,
#         [201, 200, 206],
#         [201, 200, 206],
#         [201, 200, 206]],
#
#        [[199, 198, 206],
#         [199, 198, 206],
#         [199, 198, 206],
#         ...,
#         [201, 200, 206],
#         [201, 200, 206],
#         [201, 200, 206]],
#
#        ...,
#
#        [[157, 148, 105],
#         [156, 147, 104],
#         [167, 158, 115],
#         ...,
#         [138, 135,  94],
#         [156, 153, 112],
#         [149, 144, 104]],
#
#        [[192, 179, 134],
#         [175, 162, 117],
#         [150, 137,  92],
#         ...,
#         [147, 143, 106],
#         [164, 160, 123],
#         [164, 158, 122]],
#
#        [[169, 155, 106],
#         [175, 161, 112],
#         [160, 146,  97],
# ...

# %%
fix_img.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(fix_img)

# %%
plt.show()
